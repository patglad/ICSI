# %% [markdown]
# # Mask R-CNN - Inspect ICSI Trained Model
#
# Code and visualizations to test, debug, and evaluate the Mask R-CNN model.

# %%
import os
import sys
import random
import math
import re
import time
import numpy as np
import tensorflow as tf
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Root directory of the project
ROOT_DIR = os.path.abspath("../../")

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn import utils
from mrcnn import visualize
from mrcnn.visualize import display_images
import mrcnn.model as modellib
from mrcnn.model import log

from samples.icsi import icsi

# %matplotlib inline 

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Path to Ballon trained weights
# You can download this file from the Releases page
# https://github.com/matterport/Mask_RCNN/releases
ICSI_WEIGHTS_PATH = "/path/to/mask_rcnn_icsi.h5"  # TODO: update this path
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Configurations

# %%
config = icsi.ICSIConfig()
ICSI_DIR = os.path.join(ROOT_DIR, "datasets/icsi")

# %%
# Override the training configurations with a few
# changes for inferencing.
class InferenceConfig(config.__class__):
    # Run detection on one image at a time
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

config = InferenceConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.9
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                17
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           icsi
# NUM_CLASSES                    5
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                2000
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# ## Notebook Preferences

# %%
# Device to load the neural network on.
# Useful if you're training a model on the same 
# machine, in which case use CPU and leave the
# GPU for training.
DEVICE = "/cpu:0"  # /cpu:0 or /gpu:0

# Inspect the model in training or inference modes
# values: 'inference' or 'training'
# TODO: code for 'training' test mode not ready yet
TEST_MODE = "inference"

# %%
def get_ax(rows=1, cols=1, size=16):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Adjust the size attribute to control how big to render images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

# %% [markdown]
# ## Load Validation Dataset

# %%
# Load validation dataset
dataset = icsi.ICSIDataset()
dataset.load_icsi(ICSI_DIR, "val")

# Must call before using the dataset
dataset.prepare()

print("Images: {}\nClasses: {}".format(len(dataset.image_ids), dataset.class_names))
# Out:
# Images: 56
# Classes: ['BG', 'oocyte', 'polar body', 'spermatozoon', 'pipette']

# %% [markdown]
# ## Load Model

# %%
# Create model in inference mode
with tf.device(DEVICE):
    model = modellib.MaskRCNN(mode="inference", model_dir=MODEL_DIR,
                              config=config)
# Out:
# WARNING:tensorflow:From c:\users\patry\anaconda3\envs\mask-rcnn\lib\site-packages\keras\backend\tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From c:\users\patry\anaconda3\envs\mask-rcnn\lib\site-packages\keras\backend\tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\users\patry\anaconda3\envs\mask-rcnn\lib\site-packages\keras\backend\tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From c:\users\patry\anaconda3\envs\mask-rcnn\lib\site-packages\keras\backend\tensorflow_backend.py:2139: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From c:\users\patry\anaconda3\envs\mask-rcnn\lib\site-packages\keras\backend\tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From c:\users\patry\anaconda3\envs\mask-rcnn\lib\site-packages\keras\backend\tensorflow_backend.py:2239: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From c:\users\patry\anaconda3\envs\mask-rcnn\lib\site-packages\mask_rcnn-2.1-py3.7.egg\mrcnn\model.py:341: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From c:\users\patry\anaconda3\envs\mask-rcnn\lib\site-packages\mask_rcnn-2.1-py3.7.egg\mrcnn\model.py:399: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From c:\users\patry\anaconda3\envs\mask-rcnn\lib\site-packages\mask_rcnn-2.1-py3.7.egg\mrcnn\model.py:423: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# WARNING:tensorflow:From c:\users\patry\anaconda3\envs\mask-rcnn\lib\site-packages\mask_rcnn-2.1-py3.7.egg\mrcnn\model.py:720: The name tf.sets.set_intersection is deprecated. Please use tf.sets.intersection instead.
#
# WARNING:tensorflow:From c:\users\patry\anaconda3\envs\mask-rcnn\lib\site-packages\mask_rcnn-2.1-py3.7.egg\mrcnn\model.py:722: The name tf.sparse_tensor_to_dense is deprecated. Please use tf.sparse.to_dense instead.
#
# WARNING:tensorflow:From c:\users\patry\anaconda3\envs\mask-rcnn\lib\site-packages\mask_rcnn-2.1-py3.7.egg\mrcnn\model.py:772: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.

# %%
# Set path to icsi weights file

# Download file from the Releases page and set its path
# https://github.com/matterport/Mask_RCNN/releases
# weights_path = "/path/to/mask_rcnn_icsi.h5"

weights_path = "D:\MASK-RCNN\mask_rcnn_icsi_0022.h5"
# Or, load the last model you trained
# weights_path = model.find_last()

# Load weights
print("Loading weights ", weights_path)
model.load_weights(weights_path, by_name=True)
# Out:
# Loading weights  D:\MASK-RCNN\mask_rcnn_icsi_0022.h5
# WARNING:tensorflow:From c:\users\patry\anaconda3\envs\mask-rcnn\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From c:\users\patry\anaconda3\envs\mask-rcnn\lib\site-packages\keras\backend\tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From c:\users\patry\anaconda3\envs\mask-rcnn\lib\site-packages\keras\backend\tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From c:\users\patry\anaconda3\envs\mask-rcnn\lib\site-packages\keras\backend\tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From c:\users\patry\anaconda3\envs\mask-rcnn\lib\site-packages\keras\backend\tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From c:\users\patry\anaconda3\envs\mask-rcnn\lib\site-packages\keras\backend\tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.

# %% [markdown]
# ## Run Detection

# %%
#image_id = random.choice(dataset.image_ids)
# temp: set a specific image id, not random
# e.g. image_id = 17, 10, 1, 23, 1 jest bardzo dobry do przykladu
#image_id = 2

sum_gt = 0
sum_pred = 0
for image_id in dataset.image_ids:
    image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset, config, image_id, use_mini_mask=False)
    info = dataset.image_info[image_id]
    print("image ID: {}.{} ({}) {}".format(info["source"], info["id"], image_id, 
                                           dataset.image_reference(image_id)))

    # Run object detection
    results = model.detect([image], verbose=1)

    # Display results
    ax = get_ax(1)
    r = results[0]

    number_gt = len(gt_class_id)
    print("number of ground truth ids: ", number_gt)
    sum_gt += number_gt
    print("sum_gt: ", sum_gt)

    number_pred = len(r['class_ids'])
    print("number of prediction ids: ", number_pred)
    sum_pred += number_pred
    print("sum_pred: ", sum_pred)
# Out:
# image ID: icsi.Frame01012.png (0) D:\MASK-RCNN\datasets/icsi\val\Frame01012.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  4
# sum_gt:  4
# number of prediction ids:  4
# sum_pred:  4
# image ID: icsi.Frame01024.png (1) D:\MASK-RCNN\datasets/icsi\val\Frame01024.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  4
# sum_gt:  8
# number of prediction ids:  4
# sum_pred:  8
# image ID: icsi.Frame01045.png (2) D:\MASK-RCNN\datasets/icsi\val\Frame01045.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  179.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   71.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  2
# sum_gt:  10
# number of prediction ids:  2
# sum_pred:  10
# image ID: icsi.Frame01229.png (3) D:\MASK-RCNN\datasets/icsi\val\Frame01229.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  253.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  3
# sum_gt:  13
# number of prediction ids:  1
# sum_pred:  11
# image ID: icsi.Frame01285.png (4) D:\MASK-RCNN\datasets/icsi\val\Frame01285.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  206.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   95.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  5
# sum_gt:  18
# number of prediction ids:  7
# sum_pred:  18
# image ID: icsi.Frame01317.png (5) D:\MASK-RCNN\datasets/icsi\val\Frame01317.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  181.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   75.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  6
# sum_gt:  24
# number of prediction ids:  5
# sum_pred:  23
# image ID: icsi.Frame01323.png (6) D:\MASK-RCNN\datasets/icsi\val\Frame01323.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  201.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   97.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  5
# sum_gt:  29
# number of prediction ids:  5
# sum_pred:  28
# image ID: icsi.Frame01371.png (7) D:\MASK-RCNN\datasets/icsi\val\Frame01371.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  185.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   81.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  5
# sum_gt:  34
# number of prediction ids:  5
# sum_pred:  33
# image ID: icsi.Frame01441.png (8) D:\MASK-RCNN\datasets/icsi\val\Frame01441.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  174.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   56.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  2
# sum_gt:  36
# number of prediction ids:  2
# sum_pred:  35
# image ID: icsi.Frame01531.png (9) D:\MASK-RCNN\datasets/icsi\val\Frame01531.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  175.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   60.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  4
# sum_gt:  40
# number of prediction ids:  3
# sum_pred:  38
# image ID: icsi.Frame01537.png (10) D:\MASK-RCNN\datasets/icsi\val\Frame01537.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  246.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  139.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  2
# sum_gt:  42
# number of prediction ids:  2
# sum_pred:  40
# image ID: icsi.Frame01561.png (11) D:\MASK-RCNN\datasets/icsi\val\Frame01561.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  4
# sum_gt:  46
# number of prediction ids:  4
# sum_pred:  44
# image ID: icsi.Frame01567.png (12) D:\MASK-RCNN\datasets/icsi\val\Frame01567.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  3
# sum_gt:  49
# number of prediction ids:  4
# sum_pred:  48
# image ID: icsi.Frame01579.png (13) D:\MASK-RCNN\datasets/icsi\val\Frame01579.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  3
# sum_gt:  52
# number of prediction ids:  3
# sum_pred:  51
# image ID: icsi.Frame01583.png (14) D:\MASK-RCNN\datasets/icsi\val\Frame01583.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  3
# sum_gt:  55
# number of prediction ids:  3
# sum_pred:  54
# image ID: icsi.Frame01594.png (15) D:\MASK-RCNN\datasets/icsi\val\Frame01594.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  3
# sum_gt:  58
# number of prediction ids:  3
# sum_pred:  57
# image ID: icsi.Frame01683.png (16) D:\MASK-RCNN\datasets/icsi\val\Frame01683.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  4
# sum_gt:  62
# number of prediction ids:  4
# sum_pred:  61
# image ID: icsi.Frame01975.png (17) D:\MASK-RCNN\datasets/icsi\val\Frame01975.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  154.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   42.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  3
# sum_gt:  65
# number of prediction ids:  3
# sum_pred:  64
# image ID: icsi.Frame01984.png (18) D:\MASK-RCNN\datasets/icsi\val\Frame01984.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  157.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   40.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  3
# sum_gt:  68
# number of prediction ids:  3
# sum_pred:  67
# image ID: icsi.Frame01991.png (19) D:\MASK-RCNN\datasets/icsi\val\Frame01991.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  3
# sum_gt:  71
# number of prediction ids:  3
# sum_pred:  70
# image ID: icsi.Frame02047.png (20) D:\MASK-RCNN\datasets/icsi\val\Frame02047.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# c:\users\patry\anaconda3\envs\mask-rcnn\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# number of ground truth ids:  6
# sum_gt:  77
# number of prediction ids:  7
# sum_pred:  77
# image ID: icsi.Frame02083.png (21) D:\MASK-RCNN\datasets/icsi\val\Frame02083.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  4
# sum_gt:  81
# number of prediction ids:  3
# sum_pred:  80
# image ID: icsi.Frame02173.png (22) D:\MASK-RCNN\datasets/icsi\val\Frame02173.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  226.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  102.30000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  4
# sum_gt:  85
# number of prediction ids:  3
# sum_pred:  83
# image ID: icsi.Frame02251.png (23) D:\MASK-RCNN\datasets/icsi\val\Frame02251.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  193.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   78.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  4
# sum_gt:  89
# number of prediction ids:  3
# sum_pred:  86
# image ID: icsi.Frame02254.png (24) D:\MASK-RCNN\datasets/icsi\val\Frame02254.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  195.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   80.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  4
# sum_gt:  93
# number of prediction ids:  3
# sum_pred:  89
# image ID: icsi.Frame02257.png (25) D:\MASK-RCNN\datasets/icsi\val\Frame02257.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  196.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   75.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  4
# sum_gt:  97
# number of prediction ids:  3
# sum_pred:  92
# image ID: icsi.Frame02269.png (26) D:\MASK-RCNN\datasets/icsi\val\Frame02269.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  158.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   36.20000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  3
# sum_gt:  100
# number of prediction ids:  4
# sum_pred:  96
# image ID: icsi.Frame02461.png (27) D:\MASK-RCNN\datasets/icsi\val\Frame02461.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  4
# sum_gt:  104
# number of prediction ids:  3
# sum_pred:  99
# image ID: icsi.Frame02462.png (28) D:\MASK-RCNN\datasets/icsi\val\Frame02462.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  178.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   74.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  3
# sum_gt:  107
# number of prediction ids:  3
# sum_pred:  102
# image ID: icsi.Frame02541.png (29) D:\MASK-RCNN\datasets/icsi\val\Frame02541.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  183.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   70.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  5
# sum_gt:  112
# number of prediction ids:  5
# sum_pred:  107
# image ID: icsi.Frame02587.png (30) D:\MASK-RCNN\datasets/icsi\val\Frame02587.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  189.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   85.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  6
# sum_gt:  118
# number of prediction ids:  5
# sum_pred:  112
# image ID: icsi.Frame02639.png (31) D:\MASK-RCNN\datasets/icsi\val\Frame02639.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  244.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  140.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  4
# sum_gt:  122
# number of prediction ids:  4
# sum_pred:  116
# image ID: icsi.Frame02683.png (32) D:\MASK-RCNN\datasets/icsi\val\Frame02683.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  193.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   89.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  4
# sum_gt:  126
# number of prediction ids:  3
# sum_pred:  119
# image ID: icsi.Frame02699.png (33) D:\MASK-RCNN\datasets/icsi\val\Frame02699.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  232.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  128.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  3
# sum_gt:  129
# number of prediction ids:  3
# sum_pred:  122
# image ID: icsi.Frame02723.png (34) D:\MASK-RCNN\datasets/icsi\val\Frame02723.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  184.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   80.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  4
# sum_gt:  133
# number of prediction ids:  4
# sum_pred:  126
# image ID: icsi.Frame02728.png (35) D:\MASK-RCNN\datasets/icsi\val\Frame02728.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  201.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   80.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  4
# sum_gt:  137
# number of prediction ids:  5
# sum_pred:  131
# image ID: icsi.Frame02740.png (36) D:\MASK-RCNN\datasets/icsi\val\Frame02740.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  197.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   75.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  3
# sum_gt:  140
# number of prediction ids:  4
# sum_pred:  135
# image ID: icsi.Frame02757.png (37) D:\MASK-RCNN\datasets/icsi\val\Frame02757.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  3
# sum_gt:  143
# number of prediction ids:  2
# sum_pred:  137
# image ID: icsi.Frame02906.png (38) D:\MASK-RCNN\datasets/icsi\val\Frame02906.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  2
# sum_gt:  145
# number of prediction ids:  1
# sum_pred:  138
# image ID: icsi.Frame02909.png (39) D:\MASK-RCNN\datasets/icsi\val\Frame02909.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  2
# sum_gt:  147
# number of prediction ids:  2
# sum_pred:  140
# image ID: icsi.Frame02935.png (40) D:\MASK-RCNN\datasets/icsi\val\Frame02935.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  2
# sum_gt:  149
# number of prediction ids:  1
# sum_pred:  141
# image ID: icsi.Frame02945.png (41) D:\MASK-RCNN\datasets/icsi\val\Frame02945.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  164.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   46.20000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  2
# sum_gt:  151
# number of prediction ids:  2
# sum_pred:  143
# image ID: icsi.Frame02974.png (42) D:\MASK-RCNN\datasets/icsi\val\Frame02974.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  199.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   75.30000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  4
# sum_gt:  155
# number of prediction ids:  5
# sum_pred:  148
# image ID: icsi.Frame02983.png (43) D:\MASK-RCNN\datasets/icsi\val\Frame02983.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  210.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   86.30000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  4
# sum_gt:  159
# number of prediction ids:  3
# sum_pred:  151
# image ID: icsi.Frame02995.png (44) D:\MASK-RCNN\datasets/icsi\val\Frame02995.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  194.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   72.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  3
# sum_gt:  162
# number of prediction ids:  4
# sum_pred:  155
# image ID: icsi.Frame03004.png (45) D:\MASK-RCNN\datasets/icsi\val\Frame03004.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  215.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   91.30000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  4
# sum_gt:  166
# number of prediction ids:  3
# sum_pred:  158
# image ID: icsi.Frame03013.png (46) D:\MASK-RCNN\datasets/icsi\val\Frame03013.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  191.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   76.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  4
# sum_gt:  170
# number of prediction ids:  3
# sum_pred:  161
# image ID: icsi.Frame03418.png (47) D:\MASK-RCNN\datasets/icsi\val\Frame03418.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  2
# sum_gt:  172
# number of prediction ids:  2
# sum_pred:  163
# image ID: icsi.Frame03431.png (48) D:\MASK-RCNN\datasets/icsi\val\Frame03431.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  134.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   26.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  1
# sum_gt:  173
# number of prediction ids:  2
# sum_pred:  165
# image ID: icsi.Frame03460.png (49) D:\MASK-RCNN\datasets/icsi\val\Frame03460.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  2
# sum_gt:  175
# number of prediction ids:  1
# sum_pred:  166
# image ID: icsi.Frame03477.png (50) D:\MASK-RCNN\datasets/icsi\val\Frame03477.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  207.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   99.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  5
# sum_gt:  180
# number of prediction ids:  5
# sum_pred:  171
# image ID: icsi.Frame03574.png (51) D:\MASK-RCNN\datasets/icsi\val\Frame03574.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  2
# sum_gt:  182
# number of prediction ids:  2
# sum_pred:  173
# image ID: icsi.Frame03585.png (52) D:\MASK-RCNN\datasets/icsi\val\Frame03585.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  254.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  4
# sum_gt:  186
# number of prediction ids:  3
# sum_pred:  176
# image ID: icsi.Frame03725.png (53) D:\MASK-RCNN\datasets/icsi\val\Frame03725.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  2
# sum_gt:  188
# number of prediction ids:  2
# sum_pred:  178
# image ID: icsi.Frame03929.png (54) D:\MASK-RCNN\datasets/icsi\val\Frame03929.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  254.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  4
# sum_gt:  192
# number of prediction ids:  4
# sum_pred:  182
# image ID: icsi.Frame04303.png (55) D:\MASK-RCNN\datasets/icsi\val\Frame04303.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  246.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  140.10000  float64
# image_metas              shape: (1, 17)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# number of ground truth ids:  3
# sum_gt:  195
# number of prediction ids:  3
# sum_pred:  185
# detection_correct:  94.87179487179486

# %%
detection_correct = sum_pred / sum_gt * 100
print("detection_correct: ", detection_correct)
# Out:
# detection_correct:  94.87179487179486
